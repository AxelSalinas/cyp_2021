# %% [markdown]
# <a href="https://colab.research.google.com/github/AxelSalinas/cyp_2021/blob/main/3_12_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ejemplo1 

for i in[1,2,3,4]:
  print(f"el elemento: {i}")
# Out:
# el elemento: 1
# el elemento: 2
# el elemento: 3
# el elemento: 4

# %%
coleccion=[1,2,3,4,5]
for i in coleccion:
  print(f"el elemento:{i} ")
# Out:
# el elemento:1
# el elemento:2
# el elemento:3
# el elemento:4
# el elemento:5

# %%
#ejemplo2
coleccion={"mario":20,"maria":19,"jessica":14,"luis":18}
for i in coleccion:
  print(f"Elemento: {i}")
# Out:
# Elemento: mario
# Elemento: maria
# Elemento: jessica
# Elemento: luis

# %%
coleccion={"mario":20,"maria":19,"jessica":14,"luis":18}
for i in coleccion:
  print(f"{coleccion [i]}")
# Out:
# 20
# 19
# 14
# 18

# %%
coleccion={"mario":20,"maria":19,"jessica":14,"luis":18}
for i in coleccion:
  print(f"{i}-->{coleccion[i]}")
# Out:
# mario-->20
# maria-->19
# jessica-->14
# luis-->18

# %%
coleccion={"mario":20,"maria":19,"jessica":14,"luis":18}
for clave, valor in coleccion.items():
  print(f"{clave}-->{valor}")
# Out:
# mario-->20
# maria-->19
# jessica-->14
# luis-->18

# %%
#ejemplo3
 
email= False
for i in "buenastardes@unam.mx":
  if(i=="@" ):
    email=True
if email==True:
  print("el correo es valido")
else:
  print("el correo es invalido")
# Out:
# el correo es valido

# %%
email=False
miEmail=input("introduce tu correo")
for i in miEmail:
  if(i=="@" ):
    email=True
if email:
  print("el correo es valido")
else:
  print("el correo es invalido")
# Out:
# introduce tu correohola.com
# el correo es invalido

# %%
#For-Range

for i in range (5):
  print("hola")
# Out:
# hola
# hola
# hola
# hola
# hola

# %%
for i in range (5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range (20):
  print(f"valor de la variable {i}")
# Out:
# valor de la variable 0
# valor de la variable 1
# valor de la variable 2
# valor de la variable 3
# valor de la variable 4
# valor de la variable 5
# valor de la variable 6
# valor de la variable 7
# valor de la variable 8
# valor de la variable 9
# valor de la variable 10
# valor de la variable 11
# valor de la variable 12
# valor de la variable 13
# valor de la variable 14
# valor de la variable 15
# valor de la variable 16
# valor de la variable 17
# valor de la variable 18
# valor de la variable 19

# %%
#while ejempl 1

i=1

while 1<=10:
  print("ejecución"+ str(i))
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ejecución1
# ...

# %%
i=1

while i <=10:
  print("ejecución " + str(i))
  i=i+1 #incrementa en 1 la variable
# Out:
# ejecución 1
# ejecución 2
# ejecución 3
# ejecución 4
# ejecución 5
# ejecución 6
# ejecución 7
# ejecución 8
# ejecución 9
# ejecución 10

# %%
edad= int(input("Edad: "))

while edad<0:
  print("edad negativa")
  edad=int(input("introduce edad: "))
print("puede pasar")
print("edad del aspirante: " +str(edad))
# Out:
# Edad: -12
# edad negativa
# introduce edad: -23
# edad negativa
# introduce edad: 45
# puede pasar
# edad del aspirante: 45

# %%
edad= int(input("Edad: "))

while edad<0 or edad>101:
  print("no puedes pasar")
  edad=int(input("introduce edad: "))
print("puede pasar")
print("edad del aspirante: " +str(edad))
# Out:
# Edad: 102
# no puedes pasar
# introduce edad: -34
# no puedes pasar
# introduce edad: 22
# puede pasar
# edad del aspirante: 22
